# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/My Drive/Accenture/images
# Out:
# /content/drive/.shortcut-targets-by-id/1xIqX32a8EK3WTwx9WzxcAZeSFiU-lsPs/Accenture/images

# %%
import cv2
import matplotlib.pyplot as plt
import os

# %%
images_paths_2 = [os.path.join("Гречка и перец/", i) for i in os.listdir("Гречка и перец/")]
len(images_paths_2)
# Out:
# 159

# %%
image = cv2.imread(images_paths_2[100])
image = cv2.resize(image, (300, 400))
image2 = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image2)
plt.show()

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

plt.imshow(gray, cmap='gray')
plt.show()

# %%
crop_img = gray[50:325, 50:250]

plt.imshow(crop_img, cmap='gray')
plt.show()

# %%
#sz = 35
#max_y = 0
#max_x = 0
#max_count = 400;

#for i in range(45):
#    for j in range(30):
#        smol = crop_img[(i*5):(i*5 + sz), (j*5):(j*5 + sz)]
#        if ((smol.mean()) < max_count):
#            max_y = i*5
#            max_x = j*5
#            max_count = smol.mean()

#image2 = image2[50:325, 50:250]
#img =  cv2.cvtColor(crop_img, cv2.COLOR_GRAY2RGB)
#cv2.rectangle(image2,(max_x, max_y),(max_x + sz,max_y + sz),(170, 16, 254),3)

#plt.imshow(image2)
#plt.show()

# %%
#print(max_count)

# %%
image2 = image2[50:325, 50:250]

# %%
sz = 35
max_y = 0
max_x = 0
max_count = 400;
x = []
y = []

for i in range(45):
    for j in range(30):
        smol = crop_img[(i*5):(i*5 + sz), (j*5):(j*5 + sz)]
        if ((smol.mean()) < 70 and ((len(x) == 0) or ((x[len(x) - 1] + sz < j * 5) and (y[len(x) - 1] + sz < i * 5)))):
            x.append(j*5)
            y.append(i*5)
            #max_y = i*5
            #max_x = j*5
            max_count = smol.mean()

#img =  cv2.cvtColor(crop_img, cv2.COLOR_GRAY2RGB)
for i in range(len(x)):
    cv2.rectangle(image2,(x[i], y[i]),(x[i] + sz,y[i] + sz),(170, 16, 254),3)

plt.imshow(image2)
plt.show()

# %%
count = 0

for i in range(275):
    for j in range(200):
        if (crop_img[i][j] < 55):
            count += 1

print(round(count / (275 * 200) * 100), "% брака")
# Out:
# 18 % брака
